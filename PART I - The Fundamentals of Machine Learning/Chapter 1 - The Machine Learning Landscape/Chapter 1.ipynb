# %% [markdown]
# # Chapter 1 - The Machine Learning Landscape

# %% [markdown]
# ### Example 1-1 Training and running a linear model using Scikit-Learn

# %%
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.linear_model import LinearRegression
#from sklearn.neighbors import KNeighborsRegressor

# Prepare the data
lifesat = pd.read_csv("Data/lifesat.csv")
X = lifesat[["GDP per capita (USD)"]].values
y = lifesat[["Life satisfaction"]].values

# Visualize the data
lifesat.plot(kind='scatter', grid=True,
             x="GDP per capita (USD)", y="Life satisfaction")
plt.axis([23_500, 62_500, 4, 9])
plt.show()

# Select a linear model
model = LinearRegression()
#model = KNeighborsRegressor(n_neighbors=3)

# Train the model
model.fit(X, y)

# Make a prediction for Puerto Rico
X_new = [[33_442.8]]  # Puerto Rico' GDP per capita in 2020
print(model.predict(X_new)) # outputs [[6.01610329]]”

# %% [markdown]
# # Exercises

# %% [markdown]
# ### 1. How would you define machine learning?
#
# Machine learning is giving a computer the capability to "learn" from a given data to perform a specific task. Learning in this context means being able to construct algorithms or logical decisions without having to explicitly program them, by extracting the norms or correlations from the data itself.

# %% [markdown]
# ### 2. Can you name four types of applications where it shines?
#
# - Route planning in maps applications.
# - Mail spam filters.
# - TTS applications.
# - OCR applications.
# - Chatbots.

# %% [markdown]
# ### 3. What is a labeled training set?
#
# A training set is the data that is used to create models with machine learning. A labeled training set means that the data used is also paired or complemented with a "label" containing the solution or result that it is expected from the model for each instance of the dataset.

# %% [markdown]
# ### 4. What are the two most common supervised tasks?
#
# - Regression.
# - Classification.

# %% [markdown]
# ### 5. Can you name four common unsupervised tasks?
#
# - Clustering.
# - Dimensionality reduction.
# - Anomaly detection.
# - Association rule learning.

# %% [markdown]
# ### 6. What type of algorithm would you use to allow a robot to walk in various unknown terrains?
#
# Reinforcement Learning.

# %% [markdown]
# ### 7. What type of algorithm would you use to segment your customers into multiple groups?
#
# Clustering.

# %% [markdown]
# ### 8. Would you frame the problem of spam detection as a supervised learning problem or an unsupervised learning problem?
#
# Supervised learning task (Classification).

# %% [markdown]
# ### 9. What is an online learning system?
#
# It consists in feeding data instances sequentially(steps), enabling the system to lear on the go.

# %% [markdown]
# ### 10. What is out-of-core learning?
#
# When an online learning system uses a huge dataset that doesn't fit in one system, it runs all the data but sequentially in batches.

# %% [markdown]
# ### 11. What type of algorithm relies on a similarity measure to make predictions?

# %% [markdown]
# ### 12. What is the difference between a model parameter and a model hyperparameter?

# %% [markdown]
# ### 13. What do model-based algorithms search for? What is the most common strategy they use to succeed? How do they make predictions?
